# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from ingest.catalog import DatasetCatalog
from ingest.loader import RawDatasetLoader
from ingest.fetch.csv import CsvAdapter
from ingest.fetch.sct import SocrataAdapter
from ingest.fetch.excel import ExcelAdapter
from ingest.fetch.metadata import SocrataMetadata

# %%
## servicios
catalog = DatasetCatalog()
loader = RawDatasetLoader(
    csv_adapter=CsvAdapter(),
    sct_adapter=SocrataAdapter(),
    excel_adapter=ExcelAdapter(),
)

# %%
ds = catalog.get("ban_rep")

# %%
records = list(loader.load(ds))
df = pd.DataFrame(records)
df.head()
# Out:
#         Fecha Índice COLCAP(Dato fin de año)  \
# 0  dd/mm/aaaa                         Índice
# 1  31/12/2015                              -
# 2  31/12/2016                              -
# 3  31/12/2017                              -
# 4  31/12/2018                              -
#
#   Producto Interno Bruto (PIB) nominal, Anual, metodología: 2015(Dato fin de año)  \
# 0                              Miles de millones COP
# 1                                         804.692,00
# 2                                         863.782,00
# 3                                         920.471,00
# 4                                         987.791,00
#
#   Producto Interno Bruto (PIB) nominal, Anual, metodología: 2015(Variación porcentual  anual)  \
# 0                              Miles de millones COP
# 1                                               5,48
# 2                                               7,34
# 3                                               6,56
# 4                                               7,31
#
#   Producto Interno Bruto (PIB) real, Anual, base: 2015(Dato fin de año)  \
# 0                              Miles de millones COP
# 1                                         804.692,00
# 2                                         821.489,00
# 3                                         832.656,00
# 4                                         854.008,00
#
#   Producto Interno Bruto (PIB) real, Anual, base: 2015(Variación porcentual  anual)  \
# 0                              Miles de millones COP
# 1                                               2,96
# 2                                               2,09
# 3                                               1,36
# 4                                               2,56
#
#   Crecimiento PIB real, Anual, base: 2015(Dato fin de año)  \
# 0                                                  %
# 1                                               2,96
# 2                                               2,09
# 3                                               1,36
# 4                                               2,56
#
#   Crecimiento PIB nominal, Anual, metodología: 2015(Dato fin de año)  \
# 0                                                  %
# 1                                               5,48
# 2                                               7,34
# 3                                               6,56
# 4                                               7,31
#
#   Inflación total, anual(Dato fin de año) Población(Dato fin de año)
# 0                                       %         Número de personas
# 1                                    6,77                 46.313.898
# 2                                    5,75                 46.830.116
# 3                                    4,09                 47.419.200
# 4                                    3,18                 48.258.494

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 10 columns):
#  #   Column                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                       --------------  -----
#  0   Fecha                                                                                        14 non-null     object
#  1   Índice COLCAP(Dato fin de año)                                                               11 non-null     object
#  2   Producto Interno Bruto (PIB) nominal, Anual, metodología: 2015(Dato fin de año)              11 non-null     object
#  3   Producto Interno Bruto (PIB) nominal, Anual, metodología: 2015(Variación porcentual  anual)  11 non-null     object
#  4   Producto Interno Bruto (PIB) real, Anual, base: 2015(Dato fin de año)                        11 non-null     object
#  5   Producto Interno Bruto (PIB) real, Anual, base: 2015(Variación porcentual  anual)            11 non-null     object
#  6   Crecimiento PIB real, Anual, base: 2015(Dato fin de año)                                     11 non-null     object
#  7   Crecimiento PIB nominal, Anual, metodología: 2015(Dato fin de año)                           11 non-null     object
#  8   Inflación total, anual(Dato fin de año)                                                      11 non-null     object
#  9   Población(Dato fin de año)                                                                   11 non-null     object
# dtypes: object(10)
# memory usage: 1.2+ KB

# %%
## cuantos registros por año
df['Fecha'].value_counts().sort_index()
# Out:
# Fecha
#                                                                                                   2
# 31/12/2015                                                                                        1
# 31/12/2016                                                                                        1
# 31/12/2017                                                                                        1
# 31/12/2018                                                                                        1
# 31/12/2019                                                                                        1
# 31/12/2020                                                                                        1
# 31/12/2021                                                                                        1
# 31/12/2022                                                                                        1
# 31/12/2023                                                                                        1
# 31/12/2024                                                                                        1
# Descargado de sistema del Banco de la República domingo, 23 de noviembre de 2025 9:36:53 a. m.    1
# dd/mm/aaaa                                                                                        1
# Name: count, dtype: int64
